# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Employee_1.csv")
df = pd.DataFrame(data)
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 0                             0           0
# 1                             3           1
# 2                             2           0
# 3                             5           1
# 4                             2           1
# ...                         ...         ...
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0
#
# [4653 rows x 9 columns]

# %%
df.head()
# Out:
#    Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0  Bachelors         2017  Bangalore            3   34    Male          No
# 1  Bachelors         2013       Pune            1   28  Female          No
# 2  Bachelors         2014  New Delhi            3   38  Female          No
# 3    Masters         2016  Bangalore            3   27    Male          No
# 4    Masters         2017       Pune            3   24    Male         Yes
#
#    ExperienceInCurrentDomain  LeaveOrNot
# 0                          0           0
# 1                          3           1
# 2                          2           0
# 3                          5           1
# 4                          2           1

# %%
df.tail()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
#       ExperienceInCurrentDomain  LeaveOrNot
# 4648                          4           0
# 4649                          2           1
# 4650                          5           1
# 4651                          2           0
# 4652                          4           0

# %%
df.shape
# Out:
# (4653, 9)

# %%
df.columns
# Out:
# Index(['Education', 'JoiningYear', 'City', 'PaymentTier', 'Age', 'Gender',
#        'EverBenched', 'ExperienceInCurrentDomain', 'LeaveOrNot'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4653 entries, 0 to 4652
# Data columns (total 9 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Education                  4653 non-null   str
#  1   JoiningYear                4653 non-null   int64
#  2   City                       4653 non-null   str
#  3   PaymentTier                4653 non-null   int64
#  4   Age                        4653 non-null   int64
#  5   Gender                     4653 non-null   str
#  6   EverBenched                4653 non-null   str
#  7   ExperienceInCurrentDomain  4653 non-null   int64
#  8   LeaveOrNot                 4653 non-null   int64
# dtypes: int64(5), str(4)
# memory usage: 327.3 KB

# %%
df.describe()
# Out:
#        JoiningYear  PaymentTier          Age  ExperienceInCurrentDomain  \
# count  4653.000000  4653.000000  4653.000000                4653.000000
# mean   2015.062970     2.698259    29.393295                   2.905652
# std       1.863377     0.561435     4.826087                   1.558240
# min    2012.000000     1.000000    22.000000                   0.000000
# 25%    2013.000000     3.000000    26.000000                   2.000000
# 50%    2015.000000     3.000000    28.000000                   3.000000
# 75%    2017.000000     3.000000    32.000000                   4.000000
# max    2018.000000     3.000000    41.000000                   7.000000
#
#         LeaveOrNot
# count  4653.000000
# mean      0.343864
# std       0.475047
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.isna().sum()
# Out:
# Education                    0
# JoiningYear                  0
# City                         0
# PaymentTier                  0
# Age                          0
# Gender                       0
# EverBenched                  0
# ExperienceInCurrentDomain    0
# LeaveOrNot                   0
# dtype: int64

# %%
df = df.drop(["City","Gender"],axis = 1)

# %%
df = pd.get_dummies(df)

# %%
df.corr()
# Out:
#                            JoiningYear  PaymentTier       Age  \
# JoiningYear                   1.000000    -0.096078  0.013165
# PaymentTier                  -0.096078     1.000000  0.007631
# Age                           0.013165     0.007631  1.000000
# ExperienceInCurrentDomain    -0.036525     0.018314 -0.134643
# LeaveOrNot                    0.181705    -0.197638 -0.051126
# Education_Bachelors          -0.178347     0.180820  0.011365
# Education_Masters             0.191759    -0.199632 -0.010192
# Education_PHD                -0.001362     0.011966 -0.004029
# EverBenched_No               -0.049353    -0.019207  0.016135
# EverBenched_Yes               0.049353     0.019207 -0.016135
#
#                            ExperienceInCurrentDomain  LeaveOrNot  \
# JoiningYear                                -0.036525    0.181705
# PaymentTier                                 0.018314   -0.197638
# Age                                        -0.134643   -0.051126
# ExperienceInCurrentDomain                   1.000000   -0.030504
# LeaveOrNot                                 -0.030504    1.000000
# Education_Bachelors                         0.005852   -0.118176
# Education_Masters                          -0.006584    0.145801
# Education_PHD                               0.000637   -0.038938
# EverBenched_No                             -0.001408   -0.078438
# EverBenched_Yes                             0.001408    0.078438
#
#                            Education_Bachelors  Education_Masters  \
# JoiningYear                          -0.178347           0.191759
# PaymentTier                           0.180820          -0.199632
# Age                                   0.011365          -0.010192
# ExperienceInCurrentDomain             0.005852          -0.006584
# LeaveOrNot                           -0.118176           0.145801
# Education_Bachelors                   1.000000          -0.889129
# Education_Masters                    -0.889129           1.000000
# Education_PHD                        -0.370069          -0.096126
# EverBenched_No                       -0.039043           0.013930
# EverBenched_Yes                       0.039043          -0.013930
#
#                            Education_PHD  EverBenched_No  EverBenched_Yes
# JoiningYear                    -0.001362       -0.049353         0.049353
# PaymentTier                     0.011966       -0.019207         0.019207
# Age                            -0.004029        0.016135        -0.016135
# ExperienceInCurrentDomain       0.000637       -0.001408         0.001408
# LeaveOrNot                     -0.038938       -0.078438         0.078438
# Education_Bachelors            -0.370069       -0.039043         0.039043
# Education_Masters              -0.096126        0.013930        -0.013930
# Education_PHD                   1.000000        0.056639        -0.056639
# EverBenched_No                  0.056639        1.000000        -1.000000
# EverBenched_Yes                -0.056639       -1.000000         1.000000

# %%
sns.heatmap(df.corr(),annot = True,cmap = "coolwarm")
plt.show()

# %%
df["LeaveOrNot"].value_counts()
# Out:
# LeaveOrNot
# 0    3053
# 1    1600
# Name: count, dtype: int64

# %%
sns.countplot(x = "LeaveOrNot", data = df)
plt.show()

# %%
X = df.drop("LeaveOrNot",axis = 1)
y = df["LeaveOrNot"]
X,y
# Out:
# (      JoiningYear  PaymentTier  Age  ExperienceInCurrentDomain  \
#  0            2017            3   34                          0
#  1            2013            1   28                          3
#  2            2014            3   38                          2
#  3            2016            3   27                          5
#  4            2017            3   24                          2
#  ...           ...          ...  ...                        ...
#  4648         2013            3   26                          4
#  4649         2013            2   37                          2
#  4650         2018            3   27                          5
#  4651         2012            3   30                          2
#  4652         2015            3   33                          4
#
#        Education_Bachelors  Education_Masters  Education_PHD  EverBenched_No  \
#  0                    True              False          False            True
#  1                    True              False          False            True
#  2                    True              False          False            True
#  3                   False               True          False            True
#  4                   False               True          False           False
#  ...                   ...                ...            ...             ...
#  4648                 True              False          False            True
#  4649                False               True          False            True
#  4650                False               True          False            True
#  4651                 True              False          False           False
#  4652                 True              False          False           False
#
#        EverBenched_Yes
#  0               False
#  1               False
#  2               False
#  3               False
#  4                True
#  ...               ...
#  4648            False
#  4649            False
#  4650            False
#  4651             True
#  4652             True
#
#  [4653 rows x 9 columns],
#  0       0
#  1       1
#  2       0
#  3       1
#  4       1
#         ..
#  4648    0
#  4649    1
#  4650    1
#  4651    0
#  4652    0
#  Name: LeaveOrNot, Length: 4653, dtype: int64)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 42,stratify = y)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier(5)
model.fit(X_train,y_train)
y_pred = model.predict(X_test)
y_pred
# Out:
# array([0, 0, 0, ..., 1, 0, 1], shape=(1396,))

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score

print(accuracy_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
print(recall_score(y_test,y_pred))
# Out:
# 0.7793696275071633
# [[839  77]
#  [231 249]]
# 0.51875

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.92      0.84       916
#            1       0.76      0.52      0.62       480
#
#     accuracy                           0.78      1396
#    macro avg       0.77      0.72      0.73      1396
# weighted avg       0.78      0.78      0.77      1396

# %%
from sklearn.naive_bayes import GaussianNB

model_2 = GaussianNB()
model_2.fit(X_train,y_train)
y_pred_2 = model_2.predict(X_test)
y_pred_2
# Out:
# array([1, 1, 0, ..., 0, 0, 1], shape=(1396,))

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,recall_score

print(accuracy_score(y_test,y_pred_2))
print(confusion_matrix(y_test,y_pred_2))
print(recall_score(y_test,y_pred_2))
# Out:
# 0.6224928366762178
# [[678 238]
#  [289 191]]
# 0.39791666666666664

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.70      0.74      0.72       916
#            1       0.45      0.40      0.42       480
#
#     accuracy                           0.62      1396
#    macro avg       0.57      0.57      0.57      1396
# weighted avg       0.61      0.62      0.62      1396
